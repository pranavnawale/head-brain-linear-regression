# %% [markdown]
# # head brain-linear-regression

# %% [markdown]
# ![3d-render-male-head-showing-brain_1048-5649.webp](attachment:3d-render-male-head-showing-brain_1048-5649.webp)

# %%
## install the dependencies
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
plt.rcParams['figure.figsize']=(20.0,10.0)

# %%
brain=pd.read_csv("C:\\Users\\Pranav\\Desktop\\DATA SCIENCE DATA\\CVC file\\headbrain.csv")
brain.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
# shape of dataset
brain.shape
# Out:
# (237, 4)

# %%
# information about dataset
brain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
# find ot null value in dataset
brain.isnull().sum()
# Out:
# Gender                 0
# Age Range              0
# Head Size(cm^3)        0
# Brain Weight(grams)    0
# dtype: int64

# %%
# Collecting the X and y
X=brain['Head Size(cm^3)']
Y=brain['Brain Weight(grams)']

# %%
#mean X and y 
mean_X=np.mean(X)
mean_Y=np.mean(Y)

# %%
# Total number of values 
n=len(X)
n
# Out:
# 237

# %%
# Calculating m and c
numer = 0
denom = 0
for i in range (n):
    numer += (X[i]-mean_X) * (Y[i]-mean_Y)
    denom += (X[i]-mean_X)**2

# %%
b1 = numer/denom
b0 = mean_Y - m * mean_X

# %%
b1
# Out:
# 0.26342933948939945

# %%
b0
# Out:
# 325.57342104944223

# %%
max_X = np.max(X) + 100
min_X = np.min(X) - 100

# %%
#Calculating linvalues of x and y
x = np.linspace(min_X,max_X,1000)
y = b0 + b1 * x

plt.plot(x,y,color = 'red' ,label='Regression Line')
plt.scatter(X,Y,label='Scatter Plot')
plt.xlabel('Head Size (cm^3)')
plt.ylabel('Brain Weight (gms)')
plt.show()

# %%
snumer = 0
sdenom = 0
for i in range(n):
    yp = m*X[i] + c
    snumer += (yp-mean_Y)**2
    sdenom += (Y[i] - mean_Y)**2

r2 = (snumer/sdenom)
print('R^2 value: ',r2)
# Out:
# R^2 value:  0.6393117199570001
